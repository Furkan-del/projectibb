# %%
import os
import glob 
import pandas as pd
import numpy as np
path =r'C:\Users\90545\Desktop\repos\IBB-Project\datas' 
file_list = glob.glob(path + "/*.csv")
excl_list=[]

for file in file_list:
    excl_list.append(pd.read_csv(file))

excel_merged=pd.concat(excl_list,ignore_index=True)

excel_merged.head(10)
# Out:
#              DATE_TIME  TRANSPORT_TYPE_ID TRANSPORT_TYPE_DESC  \
# 0  2020-05-07 15:00:00                2.0                 RAY
# 1  2020-05-27 14:00:00                1.0            KARAYOLU
# 2  2020-05-23 18:00:00                2.0                 RAY
# 3  2020-05-02 04:00:00                2.0                 RAY
# 4  2020-05-23 17:00:00                2.0                 RAY
# 5  2020-05-21 20:00:00                2.0                 RAY
# 6  2020-05-21 13:00:00                2.0                 RAY
# 7  2020-05-01 20:00:00                2.0                 RAY
# 8  2020-05-23 01:00:00                2.0                 RAY
# 9  2020-05-06 21:00:00                2.0                 RAY
#
#                         LINE  TRANSFER_TYPE_ID TRANSFER_TYPE  \
# 0            TAKSİM-4.LEVENT               2.0       AKTARMA
# 1                   METROBÜS               2.0        NORMAL
# 2  LEVENT - RUMELİ HİSARÜSTÜ               2.0        NORMAL
# 3            TAKSİM-4.LEVENT               2.0        NORMAL
# 4  LEVENT - RUMELİ HİSARÜSTÜ               2.0        NORMAL
# 5  TAKSİM-KABATAŞ FUNİKULERİ               2.0        NORMAL
# 6  TAKSİM-KABATAŞ FUNİKULERİ               2.0       AKTARMA
# 7            TAKSİM-4.LEVENT               2.0       AKTARMA
# 8  LEVENT - RUMELİ HİSARÜSTÜ               2.0        NORMAL
# 9            TAKSİM-4.LEVENT               2.0       AKTARMA
#
#    NUMBER_OF_PASSENGER  NUMBER_OF_PASSAGE saat transfer_type  transfertipid  \
# 0               1011.0             1028.0  NaN           NaN            NaN
# 1              13487.0            14783.0  NaN           NaN            NaN
# 2                  1.0                1.0  NaN           NaN            NaN
# 3                  2.0                2.0  NaN           NaN            NaN
# 4                  1.0                1.0  NaN           NaN            NaN
# 5                  4.0                4.0  NaN           NaN            NaN
# 6                 26.0               26.0  NaN           NaN            NaN
# 7                  2.0                2.0  NaN           NaN            NaN
# 8                  3.0                3.0  NaN           NaN            NaN
# 9                103.0              104.0  NaN           NaN            NaN
#
#   ulasimturu line  passage  passanger
# 0        NaN  NaN      NaN        NaN
# 1        NaN  NaN      NaN        NaN
# 2        NaN  NaN      NaN        NaN
# 3        NaN  NaN      NaN        NaN
# 4        NaN  NaN      NaN        NaN
# 5        NaN  NaN      NaN        NaN
# 6        NaN  NaN      NaN        NaN
# 7        NaN  NaN      NaN        NaN
# 8        NaN  NaN      NaN        NaN
# 9        NaN  NaN      NaN        NaN

# %%
ibb_data=excel_merged.copy()
ibb_data
# Out:
#                          DATE_TIME  TRANSPORT_TYPE_ID TRANSPORT_TYPE_DESC  \
# 0              2020-05-07 15:00:00                2.0                 RAY
# 1              2020-05-27 14:00:00                1.0            KARAYOLU
# 2              2020-05-23 18:00:00                2.0                 RAY
# 3              2020-05-02 04:00:00                2.0                 RAY
# 4              2020-05-23 17:00:00                2.0                 RAY
# ...                            ...                ...                 ...
# 305922  2022-10-11 05:00:00.000 PM                NaN               DENİZ
# 305923  2022-10-17 03:00:00.000 PM                NaN               DENİZ
# 305924  2022-10-13 08:00:00.000 AM                NaN               DENİZ
# 305925  2022-10-14 10:00:00.000 PM                NaN               DENİZ
# 305926  2022-10-19 06:00:00.000 AM                NaN               DENİZ
#
#                              LINE  TRANSFER_TYPE_ID TRANSFER_TYPE  \
# 0                 TAKSİM-4.LEVENT               2.0       AKTARMA
# 1                        METROBÜS               2.0        NORMAL
# 2       LEVENT - RUMELİ HİSARÜSTÜ               2.0        NORMAL
# 3                 TAKSİM-4.LEVENT               2.0        NORMAL
# 4       LEVENT - RUMELİ HİSARÜSTÜ               2.0        NORMAL
# ...                           ...               ...           ...
# 305922                MOTOR_TEKNE               3.0        Normal
# 305923                MOTOR_TEKNE               3.0        Normal
# 305924              ŞEHİR_HATLARI               3.0        Normal
# 305925              ŞEHİR_HATLARI               3.0        Normal
# 305926              ŞEHİR_HATLARI               3.0        Normal
#
#         NUMBER_OF_PASSENGER  NUMBER_OF_PASSAGE saat transfer_type  \
# 0                    1011.0             1028.0  NaN           NaN
# 1                   13487.0            14783.0  NaN           NaN
# 2                       1.0                1.0  NaN           NaN
# 3                       2.0                2.0  NaN           NaN
# 4                       1.0                1.0  NaN           NaN
# ...                     ...                ...  ...           ...
# 305922              17659.0           271992.0  NaN           NaN
# 305923              11007.0           173880.0  NaN           NaN
# 305924              10177.0            41904.0  NaN           NaN
# 305925               4158.0            17764.0  NaN           NaN
# 305926               2412.0             9936.0  NaN           NaN
#
#         transfertipid ulasimturu line  passage  passanger
# 0                 NaN        NaN  NaN      NaN        NaN
# 1                 NaN        NaN  NaN      NaN        NaN
# 2                 NaN        NaN  NaN      NaN        NaN
# 3                 NaN        NaN  NaN      NaN        NaN
# 4                 NaN        NaN  NaN      NaN        NaN
# ...               ...        ...  ...      ...        ...
# 305922            NaN        NaN  NaN      NaN        NaN
# 305923            NaN        NaN  NaN      NaN        NaN
# 305924            NaN        NaN  NaN      NaN        NaN
# 305925            NaN        NaN  NaN      NaN        NaN
# 305926            NaN        NaN  NaN      NaN        NaN
#
# [305927 rows x 15 columns]

# %%
ibb_data.set_index('DATE_TIME')
# Out:
#                             TRANSPORT_TYPE_ID TRANSPORT_TYPE_DESC  \
# DATE_TIME
# 2020-05-07 15:00:00                       2.0                 RAY
# 2020-05-27 14:00:00                       1.0            KARAYOLU
# 2020-05-23 18:00:00                       2.0                 RAY
# 2020-05-02 04:00:00                       2.0                 RAY
# 2020-05-23 17:00:00                       2.0                 RAY
# ...                                       ...                 ...
# 2022-10-11 05:00:00.000 PM                NaN               DENİZ
# 2022-10-17 03:00:00.000 PM                NaN               DENİZ
# 2022-10-13 08:00:00.000 AM                NaN               DENİZ
# 2022-10-14 10:00:00.000 PM                NaN               DENİZ
# 2022-10-19 06:00:00.000 AM                NaN               DENİZ
#
#                                                  LINE  TRANSFER_TYPE_ID  \
# DATE_TIME
# 2020-05-07 15:00:00                   TAKSİM-4.LEVENT               2.0
# 2020-05-27 14:00:00                          METROBÜS               2.0
# 2020-05-23 18:00:00         LEVENT - RUMELİ HİSARÜSTÜ               2.0
# 2020-05-02 04:00:00                   TAKSİM-4.LEVENT               2.0
# 2020-05-23 17:00:00         LEVENT - RUMELİ HİSARÜSTÜ               2.0
# ...                                               ...               ...
# 2022-10-11 05:00:00.000 PM                MOTOR_TEKNE               3.0
# 2022-10-17 03:00:00.000 PM                MOTOR_TEKNE               3.0
# 2022-10-13 08:00:00.000 AM              ŞEHİR_HATLARI               3.0
# 2022-10-14 10:00:00.000 PM              ŞEHİR_HATLARI               3.0
# 2022-10-19 06:00:00.000 AM              ŞEHİR_HATLARI               3.0
#
#                            TRANSFER_TYPE  NUMBER_OF_PASSENGER  \
# DATE_TIME
# 2020-05-07 15:00:00              AKTARMA               1011.0
# 2020-05-27 14:00:00               NORMAL              13487.0
# 2020-05-23 18:00:00               NORMAL                  1.0
# 2020-05-02 04:00:00               NORMAL                  2.0
# 2020-05-23 17:00:00               NORMAL                  1.0
# ...                                  ...                  ...
# 2022-10-11 05:00:00.000 PM        Normal              17659.0
# 2022-10-17 03:00:00.000 PM        Normal              11007.0
# 2022-10-13 08:00:00.000 AM        Normal              10177.0
# 2022-10-14 10:00:00.000 PM        Normal               4158.0
# 2022-10-19 06:00:00.000 AM        Normal               2412.0
#
#                             NUMBER_OF_PASSAGE saat transfer_type  \
# DATE_TIME
# 2020-05-07 15:00:00                    1028.0  NaN           NaN
# 2020-05-27 14:00:00                   14783.0  NaN           NaN
# 2020-05-23 18:00:00                       1.0  NaN           NaN
# 2020-05-02 04:00:00                       2.0  NaN           NaN
# 2020-05-23 17:00:00                       1.0  NaN           NaN
# ...                                       ...  ...           ...
# 2022-10-11 05:00:00.000 PM           271992.0  NaN           NaN
# 2022-10-17 03:00:00.000 PM           173880.0  NaN           NaN
# 2022-10-13 08:00:00.000 AM            41904.0  NaN           NaN
# 2022-10-14 10:00:00.000 PM            17764.0  NaN           NaN
# 2022-10-19 06:00:00.000 AM             9936.0  NaN           NaN
#
#                             transfertipid ulasimturu line  passage  passanger
# DATE_TIME
# 2020-05-07 15:00:00                   NaN        NaN  NaN      NaN        NaN
# 2020-05-27 14:00:00                   NaN        NaN  NaN      NaN        NaN
# 2020-05-23 18:00:00                   NaN        NaN  NaN      NaN        NaN
# 2020-05-02 04:00:00                   NaN        NaN  NaN      NaN        NaN
# 2020-05-23 17:00:00                   NaN        NaN  NaN      NaN        NaN
# ...                                   ...        ...  ...      ...        ...
# 2022-10-11 05:00:00.000 PM            NaN        NaN  NaN      NaN        NaN
# 2022-10-17 03:00:00.000 PM            NaN        NaN  NaN      NaN        NaN
# 2022-10-13 08:00:00.000 AM            NaN        NaN  NaN      NaN        NaN
# 2022-10-14 10:00:00.000 PM            NaN        NaN  NaN      NaN        NaN
# 2022-10-19 06:00:00.000 AM            NaN        NaN  NaN      NaN        NaN
#
# [305927 rows x 14 columns]

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.style.use('seaborn-darkgrid')
ibb_data.index=pd.to_datetime(ibb_data.index)

# %%
ibb_data[(ibb_data.TRANSPORT_TYPE_ID==1)& (ibb_data.NUMBER_OF_PASSENGER!=np.nan)]
ibb_data.reset_index()
ibb_data.index=pd.to_datetime(ibb_data.DATE_TIME)

# %%
ibb_data
ibb_data[(ibb_data.TRANSPORT_TYPE_ID==1)& (ibb_data.NUMBER_OF_PASSENGER!=np.nan)]
ibb_data.sort_index(inplace=True)

# %%
ibb_data[(ibb_data.TRANSPORT_TYPE_ID==1)& (ibb_data.NUMBER_OF_PASSENGER!=np.nan)]
# Out:
#                                DATE_TIME  TRANSPORT_TYPE_ID  \
# DATE_TIME
# 2020-05-01 00:00:00  2020-05-01 00:00:00                1.0
# 2020-05-01 00:00:00  2020-05-01 00:00:00                1.0
# 2020-05-01 00:00:00  2020-05-01 00:00:00                1.0
# 2020-05-01 00:00:00  2020-05-01 00:00:00                1.0
# 2020-05-01 00:00:00  2020-05-01 00:00:00                1.0
# ...                                  ...                ...
# 2021-05-03 23:00:00  2021-05-03 23:00:00                1.0
# 2021-05-03 23:00:00  2021-05-03 23:00:00                1.0
# 2021-05-03 23:00:00  2021-05-03 23:00:00                1.0
# 2021-05-03 23:00:00  2021-05-03 23:00:00                1.0
# 2021-05-03 23:00:00  2021-05-03 23:00:00                1.0
#
#                     TRANSPORT_TYPE_DESC      LINE  TRANSFER_TYPE_ID  \
# DATE_TIME
# 2020-05-01 00:00:00            KARAYOLU      İETT               2.0
# 2020-05-01 00:00:00            KARAYOLU  METROBÜS               2.0
# 2020-05-01 00:00:00            KARAYOLU       ÖHO               2.0
# 2020-05-01 00:00:00            KARAYOLU      İETT               2.0
# 2020-05-01 00:00:00            KARAYOLU       ÖHO               2.0
# ...                                 ...       ...               ...
# 2021-05-03 23:00:00            KARAYOLU       ÖHO               2.0
# 2021-05-03 23:00:00            KARAYOLU       ÖHO               2.0
# 2021-05-03 23:00:00            KARAYOLU      İETT               2.0
# 2021-05-03 23:00:00            KARAYOLU      İETT               2.0
# 2021-05-03 23:00:00            KARAYOLU  METROBÜS               2.0
#
#                     TRANSFER_TYPE  NUMBER_OF_PASSENGER  NUMBER_OF_PASSAGE  \
# DATE_TIME
# 2020-05-01 00:00:00       AKTARMA                  3.0                3.0
# 2020-05-01 00:00:00        NORMAL                148.0              171.0
# 2020-05-01 00:00:00       AKTARMA                  9.0                9.0
# 2020-05-01 00:00:00        NORMAL                 10.0               10.0
# 2020-05-01 00:00:00        NORMAL                 47.0               61.0
# ...                           ...                  ...                ...
# 2021-05-03 23:00:00       AKTARMA                172.0              176.0
# 2021-05-03 23:00:00        NORMAL               1957.0             2037.0
# 2021-05-03 23:00:00        NORMAL                295.0              299.0
# 2021-05-03 23:00:00       AKTARMA                 29.0               30.0
# 2021-05-03 23:00:00        NORMAL               1069.0             1078.0
#
#                     saat transfer_type  transfertipid ulasimturu line  \
# DATE_TIME
# 2020-05-01 00:00:00  NaN           NaN            NaN        NaN  NaN
# 2020-05-01 00:00:00  NaN           NaN            NaN        NaN  NaN
# 2020-05-01 00:00:00  NaN           NaN            NaN        NaN  NaN
# 2020-05-01 00:00:00  NaN           NaN            NaN        NaN  NaN
# 2020-05-01 00:00:00  NaN           NaN            NaN        NaN  NaN
# ...                  ...           ...            ...        ...  ...
# 2021-05-03 23:00:00  NaN           NaN            NaN        NaN  NaN
# 2021-05-03 23:00:00  NaN           NaN            NaN        NaN  NaN
# 2021-05-03 23:00:00  NaN           NaN            NaN        NaN  NaN
# 2021-05-03 23:00:00  NaN           NaN            NaN        NaN  NaN
# 2021-05-03 23:00:00  NaN           NaN            NaN        NaN  NaN
#
#                      passage  passanger
# DATE_TIME
# 2020-05-01 00:00:00      NaN        NaN
# 2020-05-01 00:00:00      NaN        NaN
# 2020-05-01 00:00:00      NaN        NaN
# 2020-05-01 00:00:00      NaN        NaN
# 2020-05-01 00:00:00      NaN        NaN
# ...                      ...        ...
# 2021-05-03 23:00:00      NaN        NaN
# 2021-05-03 23:00:00      NaN        NaN
# 2021-05-03 23:00:00      NaN        NaN
# 2021-05-03 23:00:00      NaN        NaN
# 2021-05-03 23:00:00      NaN        NaN
#
# [40872 rows x 15 columns]

# %%
ibb_data[(ibb_data.TRANSPORT_TYPE_ID==1)& (ibb_data.NUMBER_OF_PASSENGER!=np.nan)& (ibb_data.LINE != np.nan)]
# Out:
#                                DATE_TIME  TRANSPORT_TYPE_ID  \
# DATE_TIME
# 2020-05-01 00:00:00  2020-05-01 00:00:00                1.0
# 2020-05-01 00:00:00  2020-05-01 00:00:00                1.0
# 2020-05-01 00:00:00  2020-05-01 00:00:00                1.0
# 2020-05-01 00:00:00  2020-05-01 00:00:00                1.0
# 2020-05-01 00:00:00  2020-05-01 00:00:00                1.0
# ...                                  ...                ...
# 2021-05-03 23:00:00  2021-05-03 23:00:00                1.0
# 2021-05-03 23:00:00  2021-05-03 23:00:00                1.0
# 2021-05-03 23:00:00  2021-05-03 23:00:00                1.0
# 2021-05-03 23:00:00  2021-05-03 23:00:00                1.0
# 2021-05-03 23:00:00  2021-05-03 23:00:00                1.0
#
#                     TRANSPORT_TYPE_DESC      LINE  TRANSFER_TYPE_ID  \
# DATE_TIME
# 2020-05-01 00:00:00            KARAYOLU      İETT               2.0
# 2020-05-01 00:00:00            KARAYOLU  METROBÜS               2.0
# 2020-05-01 00:00:00            KARAYOLU       ÖHO               2.0
# 2020-05-01 00:00:00            KARAYOLU      İETT               2.0
# 2020-05-01 00:00:00            KARAYOLU       ÖHO               2.0
# ...                                 ...       ...               ...
# 2021-05-03 23:00:00            KARAYOLU       ÖHO               2.0
# 2021-05-03 23:00:00            KARAYOLU       ÖHO               2.0
# 2021-05-03 23:00:00            KARAYOLU      İETT               2.0
# 2021-05-03 23:00:00            KARAYOLU      İETT               2.0
# 2021-05-03 23:00:00            KARAYOLU  METROBÜS               2.0
#
#                     TRANSFER_TYPE  NUMBER_OF_PASSENGER  NUMBER_OF_PASSAGE  \
# DATE_TIME
# 2020-05-01 00:00:00       AKTARMA                  3.0                3.0
# 2020-05-01 00:00:00        NORMAL                148.0              171.0
# 2020-05-01 00:00:00       AKTARMA                  9.0                9.0
# 2020-05-01 00:00:00        NORMAL                 10.0               10.0
# 2020-05-01 00:00:00        NORMAL                 47.0               61.0
# ...                           ...                  ...                ...
# 2021-05-03 23:00:00       AKTARMA                172.0              176.0
# 2021-05-03 23:00:00        NORMAL               1957.0             2037.0
# 2021-05-03 23:00:00        NORMAL                295.0              299.0
# 2021-05-03 23:00:00       AKTARMA                 29.0               30.0
# 2021-05-03 23:00:00        NORMAL               1069.0             1078.0
#
#                     saat transfer_type  transfertipid ulasimturu line  \
# DATE_TIME
# 2020-05-01 00:00:00  NaN           NaN            NaN        NaN  NaN
# 2020-05-01 00:00:00  NaN           NaN            NaN        NaN  NaN
# 2020-05-01 00:00:00  NaN           NaN            NaN        NaN  NaN
# 2020-05-01 00:00:00  NaN           NaN            NaN        NaN  NaN
# 2020-05-01 00:00:00  NaN           NaN            NaN        NaN  NaN
# ...                  ...           ...            ...        ...  ...
# 2021-05-03 23:00:00  NaN           NaN            NaN        NaN  NaN
# 2021-05-03 23:00:00  NaN           NaN            NaN        NaN  NaN
# 2021-05-03 23:00:00  NaN           NaN            NaN        NaN  NaN
# 2021-05-03 23:00:00  NaN           NaN            NaN        NaN  NaN
# 2021-05-03 23:00:00  NaN           NaN            NaN        NaN  NaN
#
#                      passage  passanger
# DATE_TIME
# 2020-05-01 00:00:00      NaN        NaN
# 2020-05-01 00:00:00      NaN        NaN
# 2020-05-01 00:00:00      NaN        NaN
# 2020-05-01 00:00:00      NaN        NaN
# 2020-05-01 00:00:00      NaN        NaN
# ...                      ...        ...
# 2021-05-03 23:00:00      NaN        NaN
# 2021-05-03 23:00:00      NaN        NaN
# 2021-05-03 23:00:00      NaN        NaN
# 2021-05-03 23:00:00      NaN        NaN
# 2021-05-03 23:00:00      NaN        NaN
#
# [40872 rows x 15 columns]

# %%
ibb_data

ibb_data.plot(style='.',
        figsize=(15, 5),
        title='Zaman-Yolcu')
plt.show()
