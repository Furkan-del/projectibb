# %%
import os
import glob 
import pandas as pd
import numpy as np
path =r'C:\Users\90545\Desktop\repos\datas'
file_list = glob.glob(path + "/*.csv")
excl_list=[]

for file in file_list:
    excl_list.append(pd.read_csv(file))

excel_merged=pd.concat(excl_list,ignore_index=True)

excel_merged.head(10)
# Out:
#              DATE_TIME  TRANSPORT_TYPE_ID TRANSPORT_TYPE_DESC  \
# 0  2020-05-07 15:00:00                2.0                 RAY
# 1  2020-05-27 14:00:00                1.0            KARAYOLU
# 2  2020-05-23 18:00:00                2.0                 RAY
# 3  2020-05-02 04:00:00                2.0                 RAY
# 4  2020-05-23 17:00:00                2.0                 RAY
# 5  2020-05-21 20:00:00                2.0                 RAY
# 6  2020-05-21 13:00:00                2.0                 RAY
# 7  2020-05-01 20:00:00                2.0                 RAY
# 8  2020-05-23 01:00:00                2.0                 RAY
# 9  2020-05-06 21:00:00                2.0                 RAY
#
#                         LINE  TRANSFER_TYPE_ID TRANSFER_TYPE  \
# 0            TAKSİM-4.LEVENT               2.0       AKTARMA
# 1                   METROBÜS               2.0        NORMAL
# 2  LEVENT - RUMELİ HİSARÜSTÜ               2.0        NORMAL
# ...

# %%
ibb_data=excel_merged.copy()
ibb_data
# Out:
#                          DATE_TIME  TRANSPORT_TYPE_ID TRANSPORT_TYPE_DESC  \
# 0              2020-05-07 15:00:00                2.0                 RAY
# 1              2020-05-27 14:00:00                1.0            KARAYOLU
# 2              2020-05-23 18:00:00                2.0                 RAY
# 3              2020-05-02 04:00:00                2.0                 RAY
# 4              2020-05-23 17:00:00                2.0                 RAY
# ...                            ...                ...                 ...
# 305922  2022-10-11 05:00:00.000 PM                NaN               DENİZ
# 305923  2022-10-17 03:00:00.000 PM                NaN               DENİZ
# 305924  2022-10-13 08:00:00.000 AM                NaN               DENİZ
# 305925  2022-10-14 10:00:00.000 PM                NaN               DENİZ
# 305926  2022-10-19 06:00:00.000 AM                NaN               DENİZ
#
#                              LINE  TRANSFER_TYPE_ID TRANSFER_TYPE  \
# ...

# %%
ibb_data.isna().sum()
# Out:
# DATE_TIME                2618
# TRANSPORT_TYPE_ID       45511
# TRANSPORT_TYPE_DESC      2627
# LINE                     2627
# TRANSFER_TYPE_ID         2618
# TRANSFER_TYPE            2618
# NUMBER_OF_PASSENGER      2618
# NUMBER_OF_PASSAGE        2618
# saat                   303309
# transfer_type          303309
# transfertipid          303309
# ulasimturu             303309
# line                   303309
# passage                303309
# passanger              303309
# dtype: int64

# %%
type(ibb_data)
# Out:
# pandas.core.frame.DataFrame

# %%
ibb_data.head(20)
# Out:
#               DATE_TIME  TRANSPORT_TYPE_ID TRANSPORT_TYPE_DESC  \
# 0   2020-05-07 15:00:00                2.0                 RAY
# 1   2020-05-27 14:00:00                1.0            KARAYOLU
# 2   2020-05-23 18:00:00                2.0                 RAY
# 3   2020-05-02 04:00:00                2.0                 RAY
# 4   2020-05-23 17:00:00                2.0                 RAY
# 5   2020-05-21 20:00:00                2.0                 RAY
# 6   2020-05-21 13:00:00                2.0                 RAY
# 7   2020-05-01 20:00:00                2.0                 RAY
# 8   2020-05-23 01:00:00                2.0                 RAY
# 9   2020-05-06 21:00:00                2.0                 RAY
# 10  2020-05-28 05:00:00                1.0            KARAYOLU
# 11  2020-05-28 11:00:00                2.0                 RAY
# 12  2020-05-23 01:00:00                1.0            KARAYOLU
# 13  2020-05-27 21:00:00                2.0                 RAY
# ...

# %%
ibb_datas=ibb_data[['NUMBER_OF_PASSENGER']]
ibb_datas


ibb_datas.index=pd.to_datetime(ibb_datas.index)

# %%
ibb_datas.plot(style='.',
        figsize=(15, 5),
        title='Zaman-Yolcu')
plt.show()

# %%
# typecasting
ibb_datas.index
# Out:
# Index(['2020-05-01 00:00:00', '2020-05-01 00:00:00', '2020-05-01 00:00:00',
#        '2020-05-01 00:00:00', '2020-05-01 00:00:00', '2020-05-01 00:00:00',
#        '2020-05-01 00:00:00', '2020-05-01 00:00:00', '2020-05-01 00:00:00',
#        '2020-05-01 00:00:00',
#        ...
#                          nan,                   nan,                   nan,
#                          nan,                   nan,                   nan,
#                          nan,                   nan,                   nan,
#                          nan],
#       dtype='object', name='DATE_TIME', length=305927)

# %%
pd.to_datetime(ibb_datas.index) # converting is correct
# Out:
# DatetimeIndex(['2020-05-01 00:00:00', '2020-05-01 00:00:00',
#                '2020-05-01 00:00:00', '2020-05-01 00:00:00',
#                '2020-05-01 00:00:00', '2020-05-01 00:00:00',
#                '2020-05-01 00:00:00', '2020-05-01 00:00:00',
#                '2020-05-01 00:00:00', '2020-05-01 00:00:00',
#                ...
#                                'NaT',                 'NaT',
#                                'NaT',                 'NaT',
#                                'NaT',                 'NaT',
#                                'NaT',                 'NaT',
#                                'NaT',                 'NaT'],
#               dtype='datetime64[ns]', name='DATE_TIME', length=305927, freq=None)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.style.use('seaborn-darkgrid')
